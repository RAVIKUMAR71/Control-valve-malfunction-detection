# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import statsmodels.api as sm
import seaborn as sns
sns.set()

# %%
data = pd.read_csv('PassFlow-A.csv')

# %%
data.dropna(how='all', inplace=True)

# %%
data.isnull().sum()
# Out:
# PassFlow-A    0
# Out Put       0
# dtype: int64

# %%
data.head
# Out:
# <bound method NDFrame.head of       PassFlow-A  Out Put
# 0         79.999   32.859
# 1         79.985   32.905
# 2         80.001   32.809
# 3         80.019   32.686
# 4         80.009   32.694
# ...          ...      ...
# 8756      72.002   31.900
# 8757      72.023   31.862
# 8758      71.971   31.851
# 8759      72.001   31.791
# 8760      72.004   31.823
#
# [8683 rows x 2 columns]>

# %%
y = data['Out Put']
x1 = data['PassFlow-A']

# %%
plt.scatter(y, x1)
plt.xlabel('PassFlow-A')
plt.ylabel('Out Put')
plt.show()
